# %%
# !pip uninstall mysql-connector
# Out:
# ^C

# %%
import mysql.connector
import pandas as pd

# Connect to MySQL server
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root"
    #database="student"
)
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26756\2474012226.py in <module>
#       3
#       4 # Connect to MySQL server
# ----> 5 connection = mysql.connector.connect(
#       6     host="localhost",
#       7     user="root",
#
# ~\anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# ~\anaconda3\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     714
#     715         self.disconnect()
# --> 716         self._open_connection()
#     717         self._post_connection()
#     718
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     206         self._socket.open_connection()
#     207         self._do_handshake()
# --> 208         self._do_auth(self._user, self._password,
#     209                       self._database, self._client_flags, self._charset_id,
#     210                       self._ssl)
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     135             self._ssl_active = True
#     136
# --> 137         packet = self._protocol.make_auth(
#     138             handshake=self._handshake,
#     139             username=username, password=password, database=database,
#
# ~\anaconda3\lib\site-packages\mysql\connector\protocol.py in make_auth(self, handshake, username, password, database, charset, client_flags, max_allowed_packet, ssl_enabled, auth_plugin)
#      97                              username_bytes)
#      98
# ---> 99         packet += self._auth_response(client_flags, username, password,
#     100                                       database,
#     101                                       auth_plugin,
#
# ~\anaconda3\lib\site-packages\mysql\connector\protocol.py in _auth_response(self, client_flags, username, password, database, auth_plugin, auth_data, ssl_enabled)
#      56
#      57         try:
# ---> 58             auth = get_auth_plugin(auth_plugin)(
#      59                 auth_data,
#      60                 username=username, password=password, database=database,
#
# ~\anaconda3\lib\site-packages\mysql\connector\authentication.py in get_auth_plugin(plugin_name)
#     188             return authclass
#     189
# --> 190     raise errors.NotSupportedError(
#     191         "Authentication plugin '{0}' is not supported".format(plugin_name))
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported

# %% [markdown]
# #### Create Database

# %%
# Create a cursor object to execute SQL queries
cursor = connection.cursor()

# Create a new database
cursor.execute("CREATE DATABASE IF NOT EXISTS your_database")

# Use the created database
cursor.execute("USE your_database")

# Commit the transaction
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# #### Create Table

# %%
# Create a cursor object to execute SQL queries
cursor = connection.cursor()
# Create a new table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS student_details2 (
        Reg_Id VARCHAR(255),
        Name VARCHAR(255),
        SUB_CODE VARCHAR(255),
        SUB_NAME VARCHAR(255),
        Dept VARCHAR(255),
        Sem VARCHAR(255),
        Year VARCHAR(255)
    )
""")
# Commit the transaction
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# ### pushing records into table

# %%
df1=pd.read_excel("merged_file_updated.xlsx")
df1.shape
# Out:
# (18462, 8)

# %%
df1.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df1.head()
# Out:
#       Reg Id                    Name SUB CODE  \
# 0  L18AEC533  SAPPOGU SANDEEPU KUMAR  18ECD11
# 1  L20AEC581         AKURATHI ANITHA  18ECD12
# 2  L20AEC582      ANNAM NAGA LAKSHMI  18ECD12
# 3  L20AEC583         BALINA MANJUSHA  18ECD13
# 4  L20AEC584         DUMPALA NANDINI  18ECD12
#
#                                    SUB NAME Dept Sem  Year
# 0      Computer Organization & Architecture  ECE   V    19
# 1  Data Communication and Computer Networks  ECE   V    19
# 2  Data Communication and Computer Networks  ECE   V    19
# 3                     Programming with JAVA  ECE   V    19
# 4  Data Communication and Computer Networks  ECE   V    19

# %%
df1=df1.rename({'Reg Id':'Reg_Id',"SUB CODE":"SUB_CODE","SUB NAME":"SUB_NAME"},axis=1)

# %%
df1.head(2)
# Out:
#       Reg_Id                    Name SUB_CODE  \
# 0  L18AEC533  SAPPOGU SANDEEPU KUMAR  18ECD11
# 1  L20AEC581         AKURATHI ANITHA  18ECD12
#
#                                    SUB_NAME Dept Sem  Year
# 0      Computer Organization & Architecture  ECE   V    19
# 1  Data Communication and Computer Networks  ECE   V    19

# %%
df_dupli=df1.dropna()
df_dupli.shape
# Out:
# (16584, 7)

# %%
# Connect to MySQL server
host="localhost"
user="root"
password="Gmk@2324"
database="student"
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database
)

# Create a cursor object to execute SQL queries
cursor = connection.cursor()

# # Create MySQL table based on DataFrame structure
table_name = 'student_details2'

for row1 in range(0,len(df_dupli)):
    col1=df_dupli.iloc[row1,0]
    col2=df_dupli.iloc[row1,1]
    col3=df_dupli.iloc[row1,2]
    col4=df_dupli.iloc[row1,3]
    col5=df_dupli.iloc[row1,4]
    col6=df_dupli.iloc[row1,5]
    col7=df_dupli.iloc[row1,6]
    insert_query = f"INSERT INTO {table_name} VALUES ('{col1}','{col2}','{col3}','{col4}','{col5}','{col6}','{col7}')"
    print(insert_query)
    cursor.execute(insert_query)


# Commit the transaction
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()
# Out:
# INSERT INTO student_details2 VALUES ('L18AEC533','SAPPOGU SANDEEPU KUMAR','18ECD11',' Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC581','AKURATHI ANITHA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC582','ANNAM NAGA LAKSHMI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC583','BALINA MANJUSHA','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC584','DUMPALA NANDINI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC585','GADDAM SWARUPA RANI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC586','GANJAM SAI TANMAI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC587','KOLLIPARA MONI NAGA SUPRAJA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC588','MALLAVARAPU ABHISHEK RAMESH','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC589','MESHAPAM ABHISHEK','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC590','MORE MANIKANTA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L20AEC591','NALAM DIVYASRI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES 
18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC469','KAVURI RAJYA LAKSHMI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC470','KAVURI VENKATESWARLU','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC471','KHAGGA CHANDRA SHEKAR','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC472','KODAMAKONDLA SRILATHA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC473','KOLLA GEETHA MADHURI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC474','KOMMANABOYINA SAMBASIVA RAO','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC475','KONDA SAI KUMAR','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC476','KONDAPATURI SUREKHA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC477','KONDAREDDY JESSY GRACE','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC478','KONDEPU NAYANI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC480','KOTHAGORLA BALANAGALAKSHMI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC481','KUNCHALA NAGACHANDRIKA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC482','KUSAM KOWSHIK VENKATA ANIVESH','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC483','LAGISETTI VENKATA SAI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC484','LANKA SIVA SINDHURA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC485','LINGISETTY NAGA PAVAN KUMAR','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC486','MALLAVARAPU VENKATA BHANU PRAKASH','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC487','MANYAM SAI LAKSHMI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC488','MARUMUDI SANDEEP','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC489','MEDARAMETLA POOJITHA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC491','MOTUPALLI NAGASAI LAKSHMI','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC492','MULI VENKATA NIKHITHA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC493','MUNAGAPATI BHANU REKHA','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC494','MUNGAPATI HIMABINDU','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC495','MUPPARAJU JAYANTH KUMAR','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC496','MUPPURI C MAHESH KUMAR','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC497','NADAPANA LOHITH SESHU VENKATA GANESH','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC498','NADENDLA SRILAKSHMI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC499','NAGAMALLA MAHESH MANJUNATH','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC500','NAIDU SAI','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC501','NAKKALA LAKSHMI NARAYANA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC502','NAVYA LOKIREDDY','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC503','NAYUDU MAHESH BABU','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC504','NELAMALLI SPANDANA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC505','NIDAMANURI MOHAN GOVINDA RAJU','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC506','NULU SAI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC507','NUVVALA SATISH KUMAR','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC508','PALAVELLI SRINIVASARAO','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC509','PALIVELA NAGA CHAMUNDESWARI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC510','PANDI MAHESH','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC511','PANNEM ROHITH','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC512','PANNEM SOWMYA','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC513','PARI GOWTHAMI','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC514','PARISI RANI SWATHI SRI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC515','PASUMARTHI KARTHIK','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC516','PILLI LAKSHMI PRASANNA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC517','PILLI SHINY SHARON','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC518','PINJALA VAMSI KRISHNA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC519','PINNIBOINA BHAVANI SIVA JYOTHI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC522','PRATYUSHA YALAVARTHI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC523','PULIPATI PRATHYUSHA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC524','RAMAKURI GOPI KRISHNA','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC525','RAMAVATH VENKATESH NAIK','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC526','REDDY VENKATA SATYA KRISHNA VINAY','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC528','SAIKAM JAGADEESH','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC529','VATTIKUTI SAI KIRAN','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC530','SHAIK NAGOOR SHAREEF','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC531','SHAIK NAZIA BABI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC532','SHAIK SAHEEM FATHIMA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC533','SHAIK SAMEERA','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC534','SHAIK SHABANA NASREEN','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC535','SIVARATHRI ALEKHYA','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC536','SRI VAMSI CHUNDURU','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC537','SUNKE SIVAIAH','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC538','SURISETTY VENNELA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC539','TALAMANCHI SUPRAJA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC540','TANIKONDA SASIKUMAR','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC541','TANIMKI GAYATRI KONNI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC542','TELAGATHOTI PREM KUMAR','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC543','TELLA UDAY KIRAN','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC544','TELLAMEKALA HARI KRISHNA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC545','THANNEERU VENKATESH','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC546','THOTA REVATHI','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC547','THOTAPALLI BINDU MADHAVI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC548','THUVVADHODDI PAVAN KALYAN','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC549','UPPU VEERLA VENKAIAH','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC550','VATTIVELLA RANGA LAKSHMI PRASANNA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC551','VEMIREDDY SIVA PRAKASH REDDY','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC552','VIMJAM SIVA MACHARLA','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC553','VIPPADAPU BHARATH KUMAR','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC554','VISWANADHAPALLI HEMANTH KUMAR','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC555','VISWANADHAPALLI RAMAKRISHNA','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC556','YADAVALLI PRIYA KUMAR','18ECD11','Computer Organization & Architecture','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC557','YADLAPALLI AKHILA','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC558','YALLAVULA CHANDINI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC559','YANGALA KARTHIKESH','18ECD13','Programming with JAVA','ECE','V','19')
# INSERT INTO student_details2 VALUES ('Y19AEC560','YERLANKI CHANDINI','18ECD12','Data Communication and Computer Networks','ECE','V','19')
# INSERT INTO student_details2 VALUES ('L18AEC533','SAPPOGU SANDEEPU KUMAR','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC581','AKURATHI ANITHA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC582','ANNAM NAGA LAKSHMI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC583','BALINA MANJUSHA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC584','DUMPALA NANDINI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC585','GADDAM SWARUPA RANI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC586','GANJAM SAI TANMAI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC587','KOLLIPARA MONI NAGA SUPRAJA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC588','MALLAVARAPU ABHISHEK RAMESH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC589','MESHAPAM ABHISHEK','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC590','MORE MANIKANTA','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC591','NALAM DIVYASRI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC592','NELAPATI BABU RAO','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC593','NUNAVATHU GOWRI SHANKARI NAIK','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC594','PAMIDIBOYINA RESHMA TEJASWI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC595','PENUMUTCHA ABHISHEK','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC596','POLANA SONI SRI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC597','RAJA SAI SINDHU','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC598','SANAKA SAI TEJA','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC599','SENAPATI VENKATA SHIVA DURGA PRASAD','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC600','SHAIK MAHABOOB BASHA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L20AEC601','SIKHAKOLLI DHANUSH KUMAR','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y16AEC511','NAKKA YESU BABU','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y18AEC501','PALANATI SANDEEP','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC401','ADDANKI KISHORE BABU','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC402','ALLADI ABHISHEK NANDU','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC403','ANAGANI LIKHITH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC404','ANDRA NARESH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC405','ARIKATLA TIRUMALA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC406','BADE KRISHNA PRIYA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC407','BANDARU ANUSHA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC408','BANDIKALLA PRIYANKA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC409','BANDREDDY VENUNADH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC411','BATHALA MANISHA','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC412','BATTU SRUTHI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC413','BATTULA CHANDRASEKHAR JAYA PRAVEEN','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC414','BATTULA DILIPKUMAR','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC415','BHAMIDIPATI RAGHU ARAVIND','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC416','BHASHYAM LAKSHMI VENKATESH','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC417','BODDU SOMANADH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC418','BOMMINAYUNI PRAVEEN','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC419','BOYAPATI SRINIVASA SAI SATHWIK','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC420','CHAGANTI RAVINDRA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC421','CHALLAGALI BHUVANA','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC422','CHANNAMSETTY JASWANTH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC423','CHAPALA CHANDANA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC424','CHEGUDI RAJINEESH ROYAL','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC425','CHIRUMAMILLA NAGALAKSHMI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC426','CHOPPA SIVA SUBRAHMANYAM','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC427','DARLA AKHIL','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC428','DARLA SUSHMA SHEETHAL','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC429','DASARI RAKESH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AE
18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC512','PANNEM SOWMYA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC513','PARI GOWTHAMI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC514','PARISI RANI SWATHI SRI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC515','PASUMARTHI KARTHIK','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC516','PILLI LAKSHMI PRASANNA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC517','PILLI SHINY SHARON','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC518','PINJALA VAMSI KRISHNA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC519','PINNIBOINA BHAVANI SIVA JYOTHI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC522','PRATYUSHA YALAVARTHI','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC523','PULIPATI PRATHYUSHA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC524','RAMAKURI GOPI KRISHNA','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC525','RAMAVATH VENKATESH NAIK','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC526','REDDY VENKATA SATYA KRISHNA VINAY','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC528','SAIKAM JAGADEESH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC529','VATTIKUTI SAI KIRAN','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC530','SHAIK NAGOOR SHAREEF','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC531','SHAIK NAZIA BABI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC532','SHAIK SAHEEM FATHIMA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC533','SHAIK SAMEERA','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC534','SHAIK SHABANA NASREEN','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC535','SIVARATHRI ALEKHYA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC536','SRI VAMSI CHUNDURU','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC537','SUNKE SIVAIAH','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC538','SURISETTY VENNELA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC539','TALAMANCHI SUPRAJA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC540','TANIKONDA SASIKUMAR','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC541','TANIMKI GAYATRI KONNI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC542','TELAGATHOTI PREM KUMAR','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC543','TELLA UDAY KIRAN','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC544','TELLAMEKALA HARI KRISHNA','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC545','THANNEERU VENKATESH','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC546','THOTA REVATHI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC547','THOTAPALLI BINDU MADHAVI','18ECD21','Artificial Intelligence','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC548','THUVVADHODDI PAVAN KALYAN','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC549','UPPU VEERLA VENKAIAH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC550','VATTIVELLA RANGA LAKSHMI PRASANNA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC551','VEMIREDDY SIVA PRAKASH REDDY','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC552','VIMJAM SIVA MACHARLA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC553','VIPPADAPU BHARATH KUMAR','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC554','VISWANADHAPALLI HEMANTH KUMAR','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC555','VISWANADHAPALLI RAMAKRISHNA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC556','YADAVALLI PRIYA KUMAR','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC557','YADLAPALLI AKHILA','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC558','YALLAVULA CHANDINI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC559','YANGALA KARTHIKESH','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('Y19AEC560','YERLANKI CHANDINI','18ECD23','Embedded System Design','ECE','VI','19')
# INSERT INTO student_details2 VALUES ('L18AEC533','SAPPOGU SANDEEPU KUMAR','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC581','AKURATHI ANITHA','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC582','ANNAM NAGA LAKSHMI','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC583','BALINA MANJUSHA','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC584','DUMPALA NANDINI','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC585','GADDAM SWARUPA RANI','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC586','GANJAM SAI TANMAI','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC587','KOLLIPARA MONI NAGA SUPRAJA','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC588','MALLAVARAPU ABHISHEK RAMESH','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC589','MESHAPAM ABHISHEK','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC590','MORE MANIKANTA','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC591','NALAM DIVYASRI','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC592','NELAPATI BABU RAO','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC593','NUNAVATHU GOWRI SHANKARI NAIK','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC594','PAMIDIBOYINA RESHMA TEJASWI','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC595','PENUMUTCHA ABHISHEK','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC596','POLANA SONI SRI','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC597','RAJA SAI SINDHU','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC598','SANAKA SAI TEJA','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC599','SENAPATI VENKATA SHIVA DURGA PRASAD','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC600','SHAIK MAHABOOB BASHA','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# INSERT INTO student_details2 VALUES ('L20AEC601','SIKHAKOLLI DHANUSH KUMAR','18ECD31','Introduction to Nano-Science and Nanotechnology','ECE','VII','19')
# ...
# INSERT INTO student_details2 VALUES ('Y21AEE455','NAIDU SAIKUMAR REDDY','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE456','NAYANI MOHAN BHAVANI','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE457','NIDAMANURI HARI PRIYA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE458','NIDUBROLU CHAITANYA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE459','NIZAMPATNAM JAYA SREE','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE461','PALLEMPATI PAVANI RAMYA SRI','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE463','PANCHADARLA SRI KRISHNA KIREETI','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE464','PEDADA CHINNIKRISHNA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE466','PONUGUBATI ROSWANTHU','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE467','POTHAMSETTY SRI NAGA SAI VASANTH','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE468','PULUGU YASWANTH','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE469','PURINI INDUMATHI','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE470','PUTCHAKAYALA VENKATA NARAYANA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE471','PUVVADA JASWANTH NAGASAI MANIDEEP','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE472','RACHAMALLA NARAYANAMMA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE473','RAVURI MANIKANTA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE474','SHAIK ABDUL AZEEZ BASHA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE476','SIKHAKOLLI VENKATA MAHIJA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE477','SUVVARI VINAY VARDHAN','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE478','SYED AZMATUNNISA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE479','THOTA VINAY','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE480','TUMMA BHANU MALLIKARJUNA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE483','VALLU MALINI','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE485','VEERISETTY HARIKA LAKSHMI','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE486','VEMANA RAVANA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE487','YARRAGUNTLA HARISHBABU','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE488','YELISALA VARUN KUMAR','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE489','BALLA VENKATA NAGA RAVI TEJA','20EE605/ JO2B','Solar PV and Wind Plant Design','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L21AEE423','PUNURI BENHAR','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE490','ADABALA GANESH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE491','ADADA GANESH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE492','AGRAPU DURGAPRASAD','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE493','ALLA SONIKA REDDI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE494','BANDI VENKATA LAKSHMI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE495','BETHA NITIN','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE496','BORRA KAVYA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE497','GURRAM LAKSHMI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE498','GULLIPALLI VAMSI RAKESH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE499','KAKANI RISHI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE500','MADAPALA MAHESH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE501','MIRAPALLI RAMYA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE502','PULAGORU VEERA MOHAN','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE503','RAMAVATHU VENKATESWARLU NAIK','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE504','SEELAM THIRUMALA MURTHY BABU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE505','TALARI ADITYA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE506','TARAGALLA JYOTHI NAGA SRI ANNAPURNA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE507','ANAPARTHI YERNAIDU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE509','DASARI GOUTHAM','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE510','DUKKA HARI KRISHNA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE511','KORLA AMAR PHANI TEJA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('L22AEE513','NANNAM VIJAYARAMARAJU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y20AEE488','Y VENKATA SAI KRISHNA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE402','ADUSUMALLI VENKATA RAMANJANEYULU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE405','ANKEM BHAVANA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE406','AREPALLI PRAVEEN','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE407','BALI PRASADA RAO','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE408','BALU THIRUPATHI REDDY','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE409','BANDI PREM RAJU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE411','BHAVANAM KARTHIK REDDY','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE412','BILLA SUSMITHA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE413','BOJJA TEJASWINI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE414','BONDALAPATI RUPESH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE415','BOYINA VENUMADHAVI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE416','CHEREDDY SUJATHA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE417','CHERUKURI VENKATA SAI TEJA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE418','CHIMATA MAHESH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE419','CHIMATA PAVAN GOPI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE422','DEVARAPALLI LAKSHMAN RAO','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE423','GADE PADMAVATHI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE425','GANGUMALLA GANGA PAVAN KRISHNA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE426','GARIGIPATI KRUPA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE428','GOGULAMUDI VAMSI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE429','GOLLA PAVANI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE430','GOLLAMARI SRAVANI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE431','GOLLAMURI RUCHITHA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE432','GOLLAMURI SRIVALLI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE433','GOODUPU POORNA SEKHAR','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE434','GRANDHI VENKATA SAI NIVAS','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE435','GUDAVALLI MERCURY','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE437','GUMMADI DAVID','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE438','GUNJI GOPI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE439','IRAGALA MAHENDRA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE440','JANDRAJUPALLI RAJU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE441','KAGITALA DHARMIKA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE442','KANAGALA SYAMBABU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE443','KANAPARTHI NARENDRA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE444','KARUMANCHI PRIYANKA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE445','KASANI SIVA SAHITHA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE446','KATAKAM PALLAVI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE447','KATTUPALLI NAVEEN','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE448','KOMMANABOINA SUBRAHAMANYAM','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE449','KOTHAPALLI LALITHA SATYA SRI MALLIKA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE451','MEDAGAM VENKATA KRISHNA REDDY','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE453','MELLEMPUDI MYTHRI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE454','MOLABANTI LAKSHMI CHAITANYA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE455','NAIDU SAIKUMAR REDDY','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE456','NAYANI MOHAN BHAVANI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE457','NIDAMANURI HARI PRIYA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE458','NIDUBROLU CHAITANYA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE459','NIZAMPATNAM JAYA SREE','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE461','PALLEMPATI PAVANI RAMYA SRI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE463','PANCHADARLA SRI KRISHNA KIREETI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE464','PEDADA CHINNIKRISHNA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE466','PONUGUBATI ROSWANTHU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE467','POTHAMSETTY SRI NAGA SAI VASANTH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE468','PULUGU YASWANTH','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE469','PURINI INDUMATHI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE470','PUTCHAKAYALA VENKATA NARAYANA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE471','PUVVADA JASWANTH NAGASAI MANIDEEP','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE472','RACHAMALLA NARAYANAMMA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE473','RAVURI MANIKANTA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE474','SHAIK ABDUL AZEEZ BASHA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE476','SIKHAKOLLI VENKATA MAHIJA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE477','SUVVARI VINAY VARDHAN','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE478','SYED AZMATUNNISA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE479','THOTA VINAY','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE480','TUMMA BHANU MALLIKARJUNA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE483','VALLU MALINI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE485','VEERISETTY HARIKA LAKSHMI','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE486','VEMANA RAVANA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE487','YARRAGUNTLA HARISHBABU','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE488','YELISALA VARUN KUMAR','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
# INSERT INTO student_details2 VALUES ('Y21AEE489','BALLA VENKATA NAGA RAVI TEJA','20EEL601/SOC4','Quantitative Aptitude','EE','VI','21')
